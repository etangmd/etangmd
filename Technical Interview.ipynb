# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

survey=pd.read_csv(r"C:\Users\etang\Downloads\Survey Dataset - Technical Interview.csv")

# %% [markdown]
# ### Question 1

# %% [markdown]
# ### Load the dataset into a pandas dataframe. Name the variable as "survey"

# %%
survey=pd.read_csv(r"C:\Users\etang\Downloads\Survey Dataset - Technical Interview.csv")

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %% [markdown]
# ### Question 2

# %% [markdown]
# ### How many samples were collected on each day?

# %%
survey.collection_date.value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
survey.collection_date.unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey.collection_date.nunique()
# Out:
# 9

# %%
survey.collection_date.value_counts(ascending=True)
# Out:
# 5-31-2017     557
# 5-30-2017     582
# 5-26-2017     598
# 6-1-2017      607
# 5-29-2017     620
# 5-27-2017     665
# 5-28-2017     761
# 5-25-2017     998
# 5-24-2017    1479
# Name: collection_date, dtype: int64

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### What proportion of the total respondents were aged less than 45?

# %%
survey.head(4)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD       RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
survey['age'] < 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 survey['age'] < 45
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
survey.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
survey.age.unique()     # There is a 24ko in the string. Need to convert it
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
survey.age.replace({'24ko':24}, inplace=True)

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()
# Out:
# 25    598
# 24    449
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 41     54
# 44     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 53     12
# 61     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 62      5
# 59      5
# 65      5
# 68      4
# 63      4
# 66      4
# 70      3
# 71      2
# 74      1
# 24      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: age, dtype: int64

# %%
survey.age = survey.age.astype(int)           # To change the datatype of a column

# %%
survey.age
# Out:
# 0       26
# 1       34
# 2       25
# 3       36
# 4       22
#         ..
# 6862    25
# 6863    30
# 6864    20
# 6865    23
# 6866    33
# Name: age, Length: 6867, dtype: int32

# %%
survey[survey['age'] < 45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
6399/6867*100     #proportion of the total respondents were aged less than 45?
# Out:
# 93.18479685452162

# %% [markdown]
# ### Q4.

# %% [markdown]
# ### Create a new column in the dataframe "age_group". This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55, and 55+. The dataframe should look like this after the column creation:

# %% [markdown]
# |respone_id|  |age|  |age_group|
# |----------|  |---|  |---------|
# |1        |  |26| |25-40|
# |2      |  |34| |25-40|
# |3       |  |25| |25-40|
# |4        |  |66| |55+|

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
data=survey.copy()   #To make a copy of dataframe

# %%
data.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
#df_name.insert('new column position', 'new column name', 'new column values')  - To insert a new column at required location
#data.insert(10, 'age_group', survey.age)

# %%
data.insert(10, 'age_group', survey.age)

# %%
data.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#    age_group gender  assembly_no category    weight
# ...

# %%
data.age_group>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6862    True
# 6863    True
# 6864    True
# 6865    True
# 6866    True
# Name: age_group, Length: 6867, dtype: bool

# %%
data.age_group< 25
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 6862    False
# 6863    False
# 6864     True
# 6865     True
# 6866    False
# Name: age_group, Length: 6867, dtype: bool

# %%
data[(data.age_group>18) & (data.age_group< 25)]
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1=data[(data.age_group>18) & (data.age_group< 25)]

# %%
#data1['age_group']='18-25'    -Assiging the values to a column
data1['age_group']='18-25'
# Out:
# C:\Users\etang\AppData\Local\Temp\ipykernel_35632\2261263132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_group']='18-25'

# %%
data1.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22     18-25   Male          176       BC  0.333505
# ...

# %%
data2=data[(data.age_group>=25) & (data.age_group< 40)]

# %%
data2['age_group']='25-40'
# Out:
# C:\Users\etang\AppData\Local\Temp\ipykernel_35632\3421383473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['age_group']='25-40'

# %%
data2.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 5            6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26     25-40
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34     25-40
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied   25     25-40
# 3      RJD       RJD  Fully Dissatisfied  Somewhat Satisfied   36     25-40
# 5   Others       BJP  Somewhat Satisfied  Fully Dissatisfied   38     25-40
#
#   gender  assembly_no category    weight
# ...

# %%
data3=data[(data.age_group>=40) & (data.age_group< 55)]

# %%
data3['age_group']='40-55'
# Out:
# C:\Users\etang\AppData\Local\Temp\ipykernel_35632\3258665001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['age_group']='40-55'

# %%
data3.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 11           12       5-24-2017       Urban           Graduate
# 12           13       5-24-2017       Urban  Post - Graduation
# 28           29       5-24-2017       Rural           Graduate
# 30           31       5-24-2017       Urban           Graduate
# 33           34       5-24-2017       Urban           Graduate
#
#                  income   Vote_Now Past_Vote        CM_satisfaction  \
# 11  ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# 12   ₹ 5,000 - ₹ 10,000  Undecided     JD(U)  Somewhat Dissatisfied
# 28  ₹ 20,000 - ₹ 30,000      JD(U)       BJP        Fully Satisfied
# 30  ₹ 30,000 - ₹ 50,000       NOTA      NOTA     Fully Dissatisfied
# 33  ₹ 50,000 - ₹ 80,000        BJP       BJP        Fully Satisfied
#
#          MLA_satisfaction  age age_group gender  assembly_no category  \
# 11     Fully Dissatisfied   42     40-55   Male          183       BC
# ...

# %%
data4=data[(data.age_group>=55)]

# %%
data4['age_group']='55+'
# Out:
# C:\Users\etang\AppData\Local\Temp\ipykernel_35632\3005554677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['age_group']='55+'

# %%
data4.head()
# Out:
#      response_id collection_date urban_rural education                 income  \
# 69            70       5-24-2017       Rural  Graduate    ₹ 30,000 - ₹ 50,000
# 74            75       5-24-2017       Urban  Graduate    ₹ 30,000 - ₹ 50,000
# 121          122       5-24-2017       Rural  Graduate    ₹ 20,000 - ₹ 30,000
# 126          127       5-24-2017       Urban  Graduate  ₹ 80,000 - ₹ 1,50,000
# 183          184       5-24-2017       Rural  Graduate     ₹ 1,50,000 & above
#
#     Vote_Now     Past_Vote        CM_satisfaction    MLA_satisfaction  age  \
# 69       RJD           INC     Fully Dissatisfied     Fully Satisfied   74
# 74       BJP           BJP  Somewhat Dissatisfied  Somewhat Satisfied   70
# 121     NOTA  Did not vote     Somewhat Satisfied  Fully Dissatisfied   58
# 126     NOTA           BJP     Fully Dissatisfied  Fully Dissatisfied   56
# 183    JD(U)         JD(U)        Fully Satisfied  Fully Dissatisfied   55
#
# ...

# %%
#data=pd.concat([data1, data2, data3, data4])     -For concateration of the dataframes
data=pd.concat([data1, data2, data3, data4])

# %%
data.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22     18-25   Male          176       BC  0.333505
# ...

# %%
data.age_group.unique()
# Out:
# array(['18-25', '25-40', '40-55', '55+'], dtype=object)

# %% [markdown]
# ### Q5.

# %% [markdown]
# ### How many samples were collected for each age-group? Which age-group had the most samples?

# %%
data.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22     18-25   Male          176       BC  0.333505
# ...

# %%
data.age_group.value_counts()
# Out:
# 25-40    3844
# 18-25    1969
# 40-55     801
# 55+       128
# Name: age_group, dtype: int64

# %% [markdown]
# ### Q6.

# %% [markdown]
# ### What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
#survey.head(2)
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey.Vote_Now=='RJD'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 6862    False
# 6863     True
# 6864    False
# 6865    False
# 6866    False
# Name: Vote_Now, Length: 6867, dtype: bool

# %%
survey.Past_Vote=='RJD'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 6862    False
# 6863     True
# 6864     True
# 6865    False
# 6866    False
# Name: Past_Vote, Length: 6867, dtype: bool

# %%
survey.count()
# Out:
# response_id         6867
# collection_date     6867
# urban_rural         6867
# education           6867
# income              6867
# Vote_Now            6867
# Past_Vote           6867
# CM_satisfaction     6867
# MLA_satisfaction    6867
# age                 6867
# gender              6867
# assembly_no         6867
# category            6867
# weight              6867
# dtype: int64

# %%
survey[(survey.Past_Vote=='RJD') & (survey.Vote_Now=='RJD')].count()
# Out:
# response_id         811
# collection_date     811
# urban_rural         811
# education           811
# income              811
# Vote_Now            811
# Past_Vote           811
# CM_satisfaction     811
# MLA_satisfaction    811
# age                 811
# gender              811
# assembly_no         811
# category            811
# weight              811
# dtype: int64

# %%
811/6867
# Out:
# 0.1181010630551915

# %% [markdown]
# ### Q7.

# %% [markdown]
# ### For each day of sample collection, determine the proportion of respondents who were fully satified with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
survey[survey.CM_satisfaction=='Fully Satisfied']
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 17             18       5-24-2017       Urban                Graduate
# 28             29       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6851         6852        6-1-2017       Urban                Graduate
# 6852         6853        6-1-2017       Rural                Graduate
# 6862         6863        6-1-2017       Rural               10th Pass
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income   Vote_Now     Past_Vote  CM_satisfaction  \
# ...

# %%
survey.collection_date.value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
CM=survey[survey.CM_satisfaction=='Fully Satisfied']

# %%
CM.collection_date.value_counts()
# Out:
# 5-24-2017    146
# 5-25-2017     95
# 5-28-2017     92
# 6-1-2017      75
# 5-29-2017     73
# 5-30-2017     65
# 5-31-2017     62
# 5-26-2017     59
# 5-27-2017     54
# Name: collection_date, dtype: int64

# %%
a=CM.collection_date.value_counts()

# %%
b=survey.collection_date.value_counts()

# %%
a/b*100
# Out:
# 5-24-2017     9.871535
# 5-25-2017     9.519038
# 5-26-2017     9.866221
# 5-27-2017     8.120301
# 5-28-2017    12.089356
# 5-29-2017    11.774194
# 5-30-2017    11.168385
# 5-31-2017    11.131059
# 6-1-2017     12.355848
# Name: collection_date, dtype: float64

# %% [markdown]
# ### or

# %%
c=a/b*100
print (c)
# Out:
# 5-24-2017     9.871535
# 5-25-2017     9.519038
# 5-26-2017     9.866221
# 5-27-2017     8.120301
# 5-28-2017    12.089356
# 5-29-2017    11.774194
# 5-30-2017    11.168385
# 5-31-2017    11.131059
# 6-1-2017     12.355848
# Name: collection_date, dtype: float64

# %% [markdown]
# ### Q8.

# %% [markdown]
# ### In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey[survey.MLA_satisfaction=='Fully Dissatisfied']
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 5               6       5-24-2017       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# 6               7       5-24-2017       Urban   Graduate    BPL/Below ₹ 5,000
# 8               9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856        6-1-2017       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6857         6858        6-1-2017       Rural  12th Pass    BPL/Below ₹ 5,000
# 6862         6863        6-1-2017       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864        6-1-2017       Rural   Graduate    BPL/Below ₹ 5,000
# 6864         6865        6-1-2017       Urban   Graduate   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
MLA=survey[survey.MLA_satisfaction=='Fully Dissatisfied']

# %%
survey.collection_date.value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
MLA.collection_date.value_counts()
# Out:
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: collection_date, dtype: int64

# %%
d=MLA.collection_date.value_counts()

# %%
e=d/b*100
print(e)
# Out:
# 5-24-2017    59.972955
# 5-25-2017    63.126253
# 5-26-2017    59.030100
# 5-27-2017    60.601504
# 5-28-2017    60.709593
# 5-29-2017    56.451613
# 5-30-2017    62.027491
# 5-31-2017    57.630162
# 6-1-2017     63.426689
# Name: collection_date, dtype: float64

# %%
type(e)
# Out:
# pandas.core.series.Series

# %%
#f=pd.DataFrame(e)     -Creating a new dataframe with existing series
pd.DataFrame(e)
# Out:
#            collection_date
# 5-24-2017        59.972955
# 5-25-2017        63.126253
# 5-26-2017        59.030100
# 5-27-2017        60.601504
# 5-28-2017        60.709593
# 5-29-2017        56.451613
# 5-30-2017        62.027491
# 5-31-2017        57.630162
# 6-1-2017         63.426689

# %%
f=pd.DataFrame(e)

# %%
#type(f)      -To check the type
type (f)
# Out:
# pandas.core.frame.DataFrame

# %%
f.collection_date.plot(kind='line', figsize=(20,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q9.

# %% [markdown]
# ### Create a pivot-table (or crosstab)with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
# cell values as the count of samples---use aggfunc='count'
survey.pivot_table(index='Past_Vote', columns='Vote_Now', aggfunc='count' )
# Out:
#              CM_satisfaction                                              \
# Vote_Now                 AAP AIMIM     BJP  BSP  HAM   INC JAP(L)  JD(U)
# Past_Vote
# BJP                      7.0   1.0  1630.0  3.0  5.0  42.0  101.0  110.0
# BSP                      NaN   1.0     2.0  5.0  NaN   1.0    NaN    NaN
# Did not vote             8.0   5.0   231.0  2.0  1.0  22.0   41.0   69.0
# HAM                      2.0   NaN    25.0  NaN  1.0   NaN    3.0    2.0
# INC                      NaN   6.0     6.0  NaN  NaN  57.0   10.0    9.0
# JAP(L)                   NaN   NaN     4.0  NaN  NaN   NaN   35.0    NaN
# JD(U)                    6.0  10.0   254.0  2.0  2.0  45.0   72.0  279.0
# LJP                      NaN   NaN    76.0  1.0  NaN   4.0    3.0    6.0
# Left Front               NaN   1.0     2.0  NaN  NaN   1.0    NaN    NaN
# NOTA                     NaN   1.0    29.0  1.0  NaN   9.0    7.0    7.0
# Others                   1.0   5.0    45.0  1.0  1.0   4.0    7.0    4.0
# ...

# %% [markdown]
# ### Q10.

# %% [markdown]
# ### Repeat the above question with the cell values as the sum of "weight".

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey.pivot_table(index='Past_Vote', columns='Vote_Now',  aggfunc='sum',values='weight' )
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %% [markdown]
# ### Q11.

# %% [markdown]
# ### Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data.groupby('age_group').count()
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
type(df1)                     #To check the type
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
df1=data.groupby('age_group').count()
print(df1)
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %% [markdown]
# ### Q12.

# %% [markdown]
# ### Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data.Vote_Now=="JD(U)"
# Out:
# 4        True
# 8       False
# 14      False
# 16      False
# 18      False
#         ...
# 6649    False
# 6702    False
# 6720    False
# 6787     True
# 6851    False
# Name: Vote_Now, Length: 6742, dtype: bool

# %%
data[data.Vote_Now=="JD(U)"]
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 67             68       5-24-2017       Urban          12th Pass
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# 123           124       5-24-2017       Rural  Post - Graduation
# ...           ...             ...         ...                ...
# 5248         5249       5-24-2017       Urban  Post - Graduation
# 5956         5957        6-1-2017       Urban          12th Pass
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6499         6500       5-28-2017       Rural           Graduate
# 6787         6788        6-1-2017       Rural          10th Pass
#
#                      income Vote_Now     Past_Vote     CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...

# %%
df2=data[data.Vote_Now=="JD(U)"]

# %%
df2.groupby('age_group').count()
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              164              164          164        164     164
# 25-40              264              264          264        264     264
# 40-55               68               68           68         68      68
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           164        164              164               164  164
# 25-40           264        264              264               264  264
# 40-55            68         68               68                68   68
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         164          164       164     164
# 25-40         264          264       264     264
# 40-55          68           68        68      68
# ...

# %%
df3=df2.groupby('age_group').count()

# %% [markdown]
# ### Q13.

# %% [markdown]
# ### Join/Merge the two dataframes from question 12 and 11 with the common column as age_group.

# %%
df1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             1969             1969         1969       1969    1969
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          1969       1969             1969              1969  1969
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        1969         1969      1969    1969
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
df3
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              164              164          164        164     164
# 25-40              264              264          264        264     264
# 40-55               68               68           68         68      68
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           164        164              164               164  164
# 25-40           264        264              264               264  264
# 40-55            68         68               68                68   68
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         164          164       164     164
# 25-40         264          264       264     264
# 40-55          68           68        68      68
# ...

# %%
#pd.merge(df1, df3, on='age_group')       -To merge two dataframes
pd.merge(df1, df3, on='age_group')
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               1969               1969           1969         1969
# 25-40               3844               3844           3844         3844
# 40-55                801                801            801          801
# 55+                  128                128            128          128
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          1969        1969         1969               1969
# 25-40          3844        3844         3844               3844
# 40-55           801         801          801                801
# 55+             128         128          128                128
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    1969   1969  ...       164         164          164
# ...
